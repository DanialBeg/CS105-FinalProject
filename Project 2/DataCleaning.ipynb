# %% [markdown]
# # **Project 2 - Data Cleaning**

# %% [markdown]
# The raw dataset is the survey that was sent out to CS111 and CS105 students which compiled multiple surveys from different students into one survey. With the survey containing many more questions than the questions we asked ourselves, we must clean the dataset to only contain our survey questions. Once we've narrowed down the dataset to only our questions, we can then clean the data to remove incomplete entries and replace null values.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

pd.set_option("display.max_rows", None, "display.max_columns", None)
survey = pd.read_csv('survey-responses.csv', sep=',')
survey
# Out:
#               Timestamp  first off, which animal is a great pet?  \
# 0     12/1/2020 8:27:22                                      dog
# 1     12/1/2020 8:36:06                                      Cat
# 2     12/1/2020 8:59:20                                      rat
# 3     12/1/2020 9:02:25                                     cats
# 4     12/1/2020 9:20:14                                      cat
# 5     12/1/2020 9:22:22                                      cat
# 6     12/1/2020 9:23:26                                      Cat
# 7     12/1/2020 9:23:40                                      Dog
# 8     12/1/2020 9:23:44                                      dog
# 9     12/1/2020 9:24:51                                   turtle
# 10    12/1/2020 9:25:34                                      dog
# 11    12/1/2020 9:27:09                                      Dog
# 12    12/1/2020 9:27:46                                      cat
# ...

# %% [markdown]
# We have put the survey responses into a dataframe, but we have to clean the responses such that we discard the columns that didn't pertain to our own survey.

# %%
survey.drop(['Timestamp', 'first off, which animal is a great pet?','which class are you in?'
            ,'have you had or still have a job?','have you had or still have a part time job?'
             ,'if you answered yes to the above question, how many years have you worked?','what income level are you'
             ,'have you taken a course in game theory before? (for ucr this is math 121) '
             ,'are you familiar with the behavioral experiment known as the ultimatum game?'
             ,'what amount of money would you offer to your partner if the amount of money given to you was $20?: (Your answer should be some number between 0 and 20)'
             ,'what amount of money would you offer to your partner if the amount of money given to you was $1,000?: (Your answer should be some number between 0 and 1000)'
             ,'90:10 ($18 : $2)','70:30 ($14 : $6)','50:50 ($10 : $10)','30:70 ($6 : $14)','10:90 ($2 : $18)'
             ,'from 1 to 5, how empathetic would you consider yourself?','people are inherently selfish'
             ,'people are primarily shaped by nature rather than nurture','why did you choose this major? (select all that apply)'
             ,'if you were to go back to first year would you choose a different major?'
             ,'do you wish you had gone to a different university or community college?'
             ,'do you prefer a quarter or a semester system?','which of the following is your biggest challenge in school? (choose one)'
             ,'how does availability of classes affect your academic career? (ie personal stress, gpa, plans to graduate on time etc.)'
             ,'how overwhelmed are you by the amount of work assigned in cs classes?'
             ,'would you prefer if ucr provided more core classes to reinforce cs concepts?'
             ,'do you feel other major requirement classes affect your performance in your core cs classes (ex having to take a math, physics, or history class along with your cs classes)'
             ,'How much would you benefit if UCR provided academic resources for upper-division cs classes? (ex supplemental instruction)'
             ,'how would you compare your motivation for this quarter to your motivation for spring 2020'
             ,'how many assignments are you expected to do each week?','how often did you attend office hours in person previously?'
             ,'how often do you attend office hours online?','if you use social media, do you actively (at least once a week) post your own content?'
             ,'on average, how many hours a day do you use social media?','what is your most used social media platform'
             ,'of the following, how many platforms do you have an account for? Twitter, Instagram, Facebook, Snapchat, TikTok'
             ,'do you use social media for more than 5 minutes during lectures?'
             ,'in any hour of study time (homework, test prep, etc.), do you use social media for more than 5 minutes?'
             ,'in 2020, on average, how many hours do you spend on gaming in a week?','what\'s your main purpose for playing games?'
             ,'have you ever participated in a gaming competition?','how do you think gaming has affected your study and/or work?'
             ,'how does your family think gaming has affected your study and/or work?','which devices do you have for gaming?'
             ,'what is your favorite gaming device?'
             ,'in the 5 most recent years, how much did you spend on your gaming devices, not including gifts?'
             ,'in the 5 most recent years, how much did you spend on your games and in game purchases, not including gifts?'
             ,'how long have you been playing games?','what type of games do you play the most?','who do you play games with the most?'
             ,'how many gaming partners do you have?','which of the following dietary restrictions do you identify with?'
             ,'do you take vitamins/supplements?','overall, do you feel healthier or unhealthier during quarantine?'
             ,'how many meals did you eat each day before quarantine?'
             ,'how many days a week did you/your household cook at home before quarantine?'
             ,'how many days did you eat out in a week before quarantine?'
             ,'how many glasses/cups of water did you drink per day before quarantine?'
             ,'how many caffeinated beverages did you consume per day before quarantine?'
             ,'did you eat breakfast daily before quarantine?','how many meals did you eat each day during quarantine?'
             ,'how many days a week did you/your household cook at home during quarantine?'
             ,'how many days did you eat out in a week during quarantine?'
             ,'how many glasses/cups of water did you drink per day during quarantine?'
             ,'how many caffeinated beverages did you consume per day during quarantine?'
             ,'did you eat breakfast daily during quarantine?','Unnamed: 106'
             ,'have you experienced a loss/decrease of income because of the pandemic?','do use social media in any capacity?'
             ,'on average, when do you go to bed?','on average, when do you wake up?'
             ,'when do you have classes on fridays (all times listed are in PST)? please include labs and discussions'
             ,'when do you have classes on thurdays (all times listed are in PST)? please include labs and discussions'
             ,'when do you have classes on wednesdays (all times listed are in PST)? please include labs and discussions'
             ,'when do you have classes on tuesdays (all times listed are in PST)? please include labs and discussions'
             ,'when do you have classes on mondays (all times listed are in PST)? please include labs and discussions'
             ,'how prepared did you feel for spring 2020? (prior knowledge of the class, other resources etc)'
             ,'how many hours did spend at a job in spring 2020? (if applicable)'
             ,'did you transfer in any of these quarters? please select which one'
             ,'when do you usually start your assignments? (assuming assignments were given at least 5 days to be completed)?'
             ,'when do you feel most productive (please select based on PST)? select all that apply'
             ,'how old are you?']
            , axis='columns', inplace=True)

# %%
survey.drop(['what is your gender?','are you a transfer student?','what year of study are you in?'
             ,'what is your major?','why do you procrastinate? (select all that apply)'
             ,'what was your gpa for winter 2020? your best estimate is ok','what was your gpa for spring 2020? your best estimate is ok'
             ,'how many classes did you take spring 2020?','how many upper division classes did you take spring 2020?'
             ,'please rate the difficulty of spring 2020 with the move to remote learning in mind'
             ,'how many hours did you usually spend studying for all your classes per week in spring 2020? not including class time'
             ,'how do your grades for spring 2020 compared to your grades spring 2019?','had you taken an online class prior to the move to remote learning?'
             ,'do you have a private/quiet place to study where you live?','if school were to go back to in person instruction, would you have to commute to campus?'
             ,'how accommodating do you feel UCR has been since quarantine began (availability of academic advisors, professors accommodating for the change in learning environment,  etc.)?'
             ,'do you believe remote learning makes it easier to balance schoolwork?','do you find it easier to focus on your studies with in person learning or with remote learning?'
             ,'do you prefer studying remotely or on campus?','if we were to resume in-person education at UCR, would you prefer to take some online classes?'
             ,'have you or a family member or someone close to you contracted COVID-19 or been in contact with someone who has?'
             ,'how has the pandemic impacted your mental health?','if a covid vaccine becomes available, would you trust it enough to take it?'
             ,'if UCR re-opened before a vaccine was released, would you feel safe returning to campus?','what is your race? (pick all that apply)']
            ,axis='columns', inplace=True)

# %% [markdown]
# The columns not pertaining to our survey have been dropped, and we can now start removing invalid entries and filling NaN values.

# %%
survey = survey[survey['how has your class attendance been?'].notna()]
#survey

# %%
#survey.dtypes

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
values = {'what do you use to socialize with your friends?':'None',
          'how has your socialization with friends changed during the pandemic?':'3',
          'what is a hobby you are pursuing during the pandemic?':'None', 
          'how many hours per week do you spend on your hobby?':'0', 
          'what student orgs are you involved with this year?':'None', 
          'how many hours per week do you spend in org activities?':'0'}
survey.fillna(value=values)
# Out:
#      how has your class attendance been?  \
# 1                                    3.0
# 2                                    5.0
# 3                                    4.0
# 4                                    4.0
# 5                                    5.0
# 6                                    5.0
# 7                                    5.0
# 8                                    4.0
# 9                                    3.0
# 10                                   5.0
# 11                                   5.0
# 12                                   5.0
# 13                                   4.0
# 14                                   4.0
# 15                                   4.0
# 16                                   4.0
# 17                                   4.0
# 18                                   4.0
# 19                                   3.0
# 20                                   4.0
# 21                                   2.0
# 22                                   5.0
# ...

# %%
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#survey['what do you use to socialize with your friends?'].value_counts()
